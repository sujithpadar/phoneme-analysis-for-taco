# %%
import pandas as pd
import numpy as np

global_phone_rep = pd.read_pickle('mappings/phone_attributes.pickle')

index_to_phone = phonelogical_rep['phones']

phone_to_index = {value:key for key,value in index_to_phone.items()}

phone_to_index = {value:key for key,value in index_to_phone.items()}

global_phone_rep.keys()

glob_ph_attr_vector = global_phone_rep['phone_attribute_vectors']

# %%
np.shape(glob_ph_attr_vector)
# Out:
# (137, 57)

# %%
index_to_phone
# Out:
# {0: 'sil',
#  1: 'a',
#  2: 'aɪ',
#  3: 'aɪ˞',
#  4: 'aʊ',
#  5: 'b',
#  6: 'd',
#  7: 'dʒ',
#  8: 'e',
#  9: 'ei',
#  10: 'eo',
#  11: 'eu',
#  12: 'ey',
#  13: 'eæ',
#  14: 'eø',
#  15: 'eɑ',
#  16: 'eɪ',
#  17: 'f',
#  18: 'g',
#  19: 'h',
#  20: 'i',
#  21: 'ie',
#  22: 'io',
#  23: 'iu',
#  24: 'iy',
#  25: 'iæ',
#  26: 'iø',
#  27: 'iɑ',
#  28: 'j',
#  29: 'k',
#  30: 'kʰ',
#  31: 'l',
#  32: 'l̩',
#  33: 'm',
#  34: 'm̩',
#  35: 'n',
#  36: 'n̩',
#  37: 'o',
#  38: 'oe',
#  39: 'oi',
#  40: 'ou',
#  41: 'oɑ',
#  42: 'oʊ',
#  43: 'p',
#  44: 'pʰ',
#  45: 'r',
#  46: 's',
#  47: 't',
#  48: 'ts',
#  49: 'tʃ',
#  50: 'tʰ',
#  51: 'u',
#  52: 'ue',
#  53: 'ui',
#  54: 'uo',
#  55: 'uɑ',
#  56: 'v',
#  57: 'w',
#  58: 'y',
#  59: 'ye',
#  60: 'yi',
#  61: 'yæ',
#  62: 'yø',
#  63: 'z',
#  64: 'æ',
#  65: 'æe',
#  66: 'æi',
#  67: 'æy',
#  68: 'æø',
#  69: 'ð',
#  70: 'õ',
#  71: 'ø',
#  72: 'øe',
#  73: 'øi',
#  74: 'øy',
#  75: 'øæ',
#  76: 'ŋ',
#  77: 'œ',
#  78: 'ɑ',
# ...

# %%
phone_to_index
# Out:
# {'sil': 0,
#  'a': 1,
#  'aɪ': 2,
#  'aɪ˞': 3,
#  'aʊ': 4,
#  'b': 5,
#  'd': 6,
#  'dʒ': 7,
#  'e': 8,
#  'ei': 9,
#  'eo': 10,
#  'eu': 11,
#  'ey': 12,
#  'eæ': 13,
#  'eø': 14,
#  'eɑ': 15,
#  'eɪ': 16,
#  'f': 17,
#  'g': 18,
#  'h': 19,
#  'i': 20,
#  'ie': 21,
#  'io': 22,
#  'iu': 23,
#  'iy': 24,
#  'iæ': 25,
#  'iø': 26,
#  'iɑ': 27,
#  'j': 28,
#  'k': 29,
#  'kʰ': 30,
#  'l': 31,
#  'l̩': 32,
#  'm': 33,
#  'm̩': 34,
#  'n': 35,
#  'n̩': 36,
#  'o': 37,
#  'oe': 38,
#  'oi': 39,
#  'ou': 40,
#  'oɑ': 41,
#  'oʊ': 42,
#  'p': 43,
#  'pʰ': 44,
#  'r': 45,
#  's': 46,
#  't': 47,
#  'ts': 48,
#  'tʃ': 49,
#  'tʰ': 50,
#  'u': 51,
#  'ue': 52,
#  'ui': 53,
#  'uo': 54,
#  'uɑ': 55,
#  'v': 56,
#  'w': 57,
#  'y': 58,
#  'ye': 59,
#  'yi': 60,
#  'yæ': 61,
#  'yø': 62,
#  'z': 63,
#  'æ': 64,
#  'æe': 65,
#  'æi': 66,
#  'æy': 67,
#  'æø': 68,
#  'ð': 69,
#  'õ': 70,
#  'ø': 71,
#  'øe': 72,
#  'øi': 73,
#  'øy': 74,
#  'øæ': 75,
#  'ŋ': 76,
#  'œ': 77,
#  'ɑ': 78,
# ...
